# %% [markdown]
# ### Imports

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # Silence tensorflow alerts
import tensorflow as tf

# %%
import sys
path_to_software_folder = sys.path[0][:-23] + 'software/'
sys.path.append(path_to_software_folder) # Add the software folder to path, note that outside of the "demo" folder you will need to manually set "path_to_software_folder"
from DoubleWell import DoubleWell
from ProcessingNets import *
from Network_Passive import *
from FlowRES_MCMC_Passive import *
from Plotting import *

# %% [markdown]
# # Define the model

# %%
start_point = [-1.0, 0]
duration = 1.6
traj_len = 32
D_t = 0.15
mu = 0.1
dt = duration/traj_len
tran_coeff = np.sqrt(2*D_t*dt)
pot_coeff = mu*dt

# %%
params = {'x_0' :  1.0,
          'k_x' :  2.0,
          'k_y' :  10.0,
          'k_BH' : 15,
          'target': 7.5}
Double_Well = DoubleWell(params=params)
Double_Well.plot_energy_surface_DW()

# %% [markdown]
# # Create a network

# %%
Affine_Wave_params = {'num_filters': 32,
                      'kernel_size': 3,
                      'num_dilated_conv_layers': 3}

Num_Layers = 2    # number of scales
FLOWS_pre_LAYER = 1    # For passive, leave this as 1
Pos_flows_per_Flow = 10    # Number of complete positional flow steps

Ang_flows_per_Flow = 0.00    # Leave this as 0
CCs = 0.00    # For passive, leave this as 0
Pos_CC_per_Flow = 0.00    # For passive, leave this as 0
Ang_CC_per_Flow = 0.00    # Leave this as 0, this term lets positions affect angles

Net = CreateFlowNet(Num_Layers, FLOWS_pre_LAYER,
                    Pos_flows_per_Flow, Ang_flows_per_Flow, 
                    CCs, Pos_CC_per_Flow, Ang_CC_per_Flow,
                    Affine_WaveNet=Wave_unit, Affine_WaveParams=Affine_Wave_params, 
                    potential_grad=Double_Well.batch_gradient,
                    start=start_point, tran_coeff=tran_coeff, pot_coeff=pot_coeff,
                    max_len=traj_len, dim=3)
# Out:
# ... creating network
# Network created.

# %% [markdown]
# # Explore Using FlowRES

# %%
num_chains = 30000
num_iterations = 100

FlowRES_Passive_DoubleWell = FlowRes_MCMC(Net, num_chains, Chain_Initialiser_Passive, Double_Well)    # define the FlowRES framework for this system
FlowRES_Passive_DoubleWell.Compile_ML_Model(batch_size=512, lr=0.001)    # compile the network so that it is ready to train    

all_FlowRES_hists = FlowRES_Passive_DoubleWell.Explore(iterations=num_iterations, return_hists=True, hist_bins=np.linspace(-2,2,200))[0]
# Out:
# Iteration 1 / 100
# /home/cs-solomon.asghar/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#     accepted 81.72666666666667% of non-local proposals
# Train on 24623 samples
# 24623/24623 [==============================] - 34s 1ms/sample - loss: 31.5312
#
#     network trained with non-local samples
# Iteration 2 / 100
#     accepted 50.839999999999996% of non-local proposals
# Train on 29057 samples
# 29057/29057 [==============================] - 16s 561us/sample - loss: 29.1497
#
#     network trained with non-local samples
# Iteration 3 / 100
#     accepted 43.53666666666667% of non-local proposals
# Train on 29859 samples
# 29859/29859 [==============================] - 17s 563us/sample - loss: 26.2830
#
#     network trained with non-local samples
# Iteration 4 / 100
#     accepted 39.65% of non-local proposals
# Train on 29979 samples
# 29979/29979 [==============================] - 17s 561us/sample - loss: 23.9819
#
#     network trained with non-local samples
# Iteration 5 / 100
#     accepted 43.266666666666666% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: 21.3937
#
#     network trained with non-local samples
# Iteration 6 / 100
#     accepted 40.92% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 557us/sample - loss: 19.0758
#
#     network trained with non-local samples
# Iteration 7 / 100
#     accepted 41.00333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: 16.7258
#
#     network trained with non-local samples
# Iteration 8 / 100
#     accepted 40.163333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: 14.4091
#
#     network trained with non-local samples
# Iteration 9 / 100
#     accepted 42.973333333333336% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: 11.7808
#
#     network trained with non-local samples
# Iteration 10 / 100
#     accepted 43.31666666666666% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: 8.8946
#
#     network trained with non-local samples
# Iteration 11 / 100
#     accepted 42.79333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: 5.7497
#
#     network trained with non-local samples
# Iteration 12 / 100
#     accepted 42.88666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: 2.0165
#
#     network trained with non-local samples
# Iteration 13 / 100
#     accepted 40.973333333333336% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -2.2304
#
#     network trained with non-local samples
# Iteration 14 / 100
#     accepted 43.32666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -8.2303
#
#     network trained with non-local samples
# Iteration 15 / 100
#     accepted 43.45% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -16.4116
#
#     network trained with non-local samples
# Iteration 16 / 100
#     accepted 42.51333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -26.6525
#
#     network trained with non-local samples
# Iteration 17 / 100
#     accepted 42.59% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -38.9505
#
#     network trained with non-local samples
# Iteration 18 / 100
#     accepted 42.1% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -52.6103
#
#     network trained with non-local samples
# Iteration 19 / 100
#     accepted 43.06666666666666% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -65.8058
#
#     network trained with non-local samples
# Iteration 20 / 100
#     accepted 46.836666666666666% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -78.3544
#
#     network trained with non-local samples
# Iteration 21 / 100
#     accepted 45.83% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -86.6818
#
#     network trained with non-local samples
# Iteration 22 / 100
#     accepted 46.2% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 563us/sample - loss: -92.0399
#
#     network trained with non-local samples
# Iteration 23 / 100
#     accepted 48.47% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -95.6340
#
#     network trained with non-local samples
# Iteration 24 / 100
#     accepted 48.33% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -98.3698
#
#     network trained with non-local samples
# Iteration 25 / 100
#     accepted 49.0% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 562us/sample - loss: -100.1012
#
#     network trained with non-local samples
# Iteration 26 / 100
#     accepted 50.07% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -101.5737
#
#     network trained with non-local samples
# Iteration 27 / 100
#     accepted 50.29333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.3713
#
#     network trained with non-local samples
# Iteration 28 / 100
#     accepted 49.71% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.9140
#
#     network trained with non-local samples
# Iteration 29 / 100
#     accepted 52.11666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -103.4095
#
#     network trained with non-local samples
# Iteration 30 / 100
#     accepted 53.54666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -103.6185
#
#     network trained with non-local samples
# Iteration 31 / 100
#     accepted 51.36333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -103.4805
#
#     network trained with non-local samples
# Iteration 32 / 100
#     accepted 52.68333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 563us/sample - loss: -103.6413
#
#     network trained with non-local samples
# Iteration 33 / 100
#     accepted 54.2% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -103.4472
#
#     network trained with non-local samples
# Iteration 34 / 100
#     accepted 53.690000000000005% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -103.3657
#
#     network trained with non-local samples
# Iteration 35 / 100
#     accepted 52.059999999999995% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -103.2186
#
#     network trained with non-local samples
# Iteration 36 / 100
#     accepted 49.93% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -103.1874
#
#     network trained with non-local samples
# Iteration 37 / 100
#     accepted 53.55% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -103.1904
#
#     network trained with non-local samples
# Iteration 38 / 100
#     accepted 53.346666666666664% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -103.0792
#
#     network trained with non-local samples
# Iteration 39 / 100
#     accepted 54.67666666666666% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -103.0531
#
#     network trained with non-local samples
# Iteration 40 / 100
#     accepted 54.843333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.8573
#
#     network trained with non-local samples
# Iteration 41 / 100
#     accepted 54.776666666666664% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.7141
#
#     network trained with non-local samples
# Iteration 42 / 100
#     accepted 56.57% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.6502
#
#     network trained with non-local samples
# Iteration 43 / 100
#     accepted 55.83% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.6254
#
#     network trained with non-local samples
# Iteration 44 / 100
#     accepted 56.32333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 557us/sample - loss: -102.6314
#
#     network trained with non-local samples
# Iteration 45 / 100
#     accepted 57.11000000000001% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.4892
#
#     network trained with non-local samples
# Iteration 46 / 100
#     accepted 57.24333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.3810
#
#     network trained with non-local samples
# Iteration 47 / 100
#     accepted 56.123333333333335% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 557us/sample - loss: -102.3391
#
#     network trained with non-local samples
# Iteration 48 / 100
#     accepted 57.95333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.3096
#
#     network trained with non-local samples
# Iteration 49 / 100
#     accepted 58.5% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.2162
#
#     network trained with non-local samples
# Iteration 50 / 100
#     accepted 58.699999999999996% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.2145
#
#     network trained with non-local samples
# Iteration 51 / 100
#     accepted 54.03666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.1931
#
#     network trained with non-local samples
# Iteration 52 / 100
#     accepted 58.166666666666664% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.2598
#
#     network trained with non-local samples
# Iteration 53 / 100
#     accepted 59.11666666666666% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 563us/sample - loss: -102.1830
#
#     network trained with non-local samples
# Iteration 54 / 100
#     accepted 57.06% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.0926
#
#     network trained with non-local samples
# Iteration 55 / 100
#     accepted 60.943333333333335% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 568us/sample - loss: -102.1311
#
#     network trained with non-local samples
# Iteration 56 / 100
#     accepted 61.34666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 570us/sample - loss: -102.1939
#
#     network trained with non-local samples
# Iteration 57 / 100
#     accepted 56.89999999999999% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 563us/sample - loss: -102.1160
#
#     network trained with non-local samples
# Iteration 58 / 100
#     accepted 61.34666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 564us/sample - loss: -102.1047
#
#     network trained with non-local samples
# Iteration 59 / 100
#     accepted 59.52666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.1084
#
#     network trained with non-local samples
# Iteration 60 / 100
#     accepted 60.93666666666666% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.2638
#
#     network trained with non-local samples
# Iteration 61 / 100
#     accepted 61.96% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.1533
#
#     network trained with non-local samples
# Iteration 62 / 100
#     accepted 60.919999999999995% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -101.9754
#
#     network trained with non-local samples
# Iteration 63 / 100
#     accepted 61.873333333333335% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.0731
#
#     network trained with non-local samples
# Iteration 64 / 100
#     accepted 64.09% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 558us/sample - loss: -102.0915
#
#     network trained with non-local samples
# Iteration 65 / 100
#     accepted 61.49% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -102.0945
#
#     network trained with non-local samples
# Iteration 66 / 100
#     accepted 64.18% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.0423
#
#     network trained with non-local samples
# Iteration 67 / 100
#     accepted 63.39333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.0913
#
#     network trained with non-local samples
# Iteration 68 / 100
#     accepted 64.33666666666666% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -102.1307
#
#     network trained with non-local samples
# Iteration 69 / 100
#     accepted 63.81333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.0502
#
#     network trained with non-local samples
# Iteration 70 / 100
#     accepted 59.78% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -102.0917
#
#     network trained with non-local samples
# Iteration 71 / 100
#     accepted 64.44333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.0525
#
#     network trained with non-local samples
# Iteration 72 / 100
#     accepted 62.9% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.0141
#
#     network trained with non-local samples
# Iteration 73 / 100
#     accepted 65.75333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.0649
#
#     network trained with non-local samples
# Iteration 74 / 100
#     accepted 63.70666666666666% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 558us/sample - loss: -102.0480
#
#     network trained with non-local samples
# Iteration 75 / 100
#     accepted 65.08333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.0274
#
#     network trained with non-local samples
# Iteration 76 / 100
#     accepted 64.35666666666665% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 557us/sample - loss: -101.9740
#
#     network trained with non-local samples
# Iteration 77 / 100
#     accepted 63.18333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -101.8908
#
#     network trained with non-local samples
# Iteration 78 / 100
#     accepted 63.949999999999996% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -101.9522
#
#     network trained with non-local samples
# Iteration 79 / 100
#     accepted 65.00666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -101.8812
#
#     network trained with non-local samples
# Iteration 80 / 100
#     accepted 66.10333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -101.9615
#
#     network trained with non-local samples
# Iteration 81 / 100
#     accepted 65.14333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -101.9679
#
#     network trained with non-local samples
# Iteration 82 / 100
#     accepted 65.64999999999999% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.0260
#
#     network trained with non-local samples
# Iteration 83 / 100
#     accepted 66.35333333333332% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 558us/sample - loss: -101.9781
#
#     network trained with non-local samples
# Iteration 84 / 100
#     accepted 65.73333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -101.9693
#
#     network trained with non-local samples
# Iteration 85 / 100
#     accepted 66.37333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -101.9705
#
#     network trained with non-local samples
# Iteration 86 / 100
#     accepted 67.22333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 558us/sample - loss: -101.9292
#
#     network trained with non-local samples
# Iteration 87 / 100
#     accepted 67.25% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.0052
#
#     network trained with non-local samples
# Iteration 88 / 100
#     accepted 65.32666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -101.9933
#
#     network trained with non-local samples
# Iteration 89 / 100
#     accepted 65.88666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -101.9593
#
#     network trained with non-local samples
# Iteration 90 / 100
#     accepted 68.61% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -101.9805
#
#     network trained with non-local samples
# Iteration 91 / 100
#     accepted 66.39% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -101.9934
#
#     network trained with non-local samples
# Iteration 92 / 100
#     accepted 68.29666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.1501
#
#     network trained with non-local samples
# Iteration 93 / 100
#     accepted 66.80333333333334% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.0371
#
#     network trained with non-local samples
# Iteration 94 / 100
#     accepted 67.10666666666667% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 562us/sample - loss: -101.9534
#
#     network trained with non-local samples
# Iteration 95 / 100
#     accepted 68.20333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 558us/sample - loss: -101.9074
#
#     network trained with non-local samples
# Iteration 96 / 100
#     accepted 68.35% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -101.9917
#
#     network trained with non-local samples
# Iteration 97 / 100
#     accepted 67.31% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 560us/sample - loss: -102.0376
#
#     network trained with non-local samples
# Iteration 98 / 100
#     accepted 67.06333333333333% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 559us/sample - loss: -102.0083
#
#     network trained with non-local samples
# Iteration 99 / 100
#     accepted 67.47999999999999% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 558us/sample - loss: -101.9738
#
#     network trained with non-local samples
# Iteration 100 / 100
#     accepted 65.31% of non-local proposals
# Train on 30000 samples
# 30000/30000 [==============================] - 17s 561us/sample - loss: -101.9943
#
#     network trained with non-local samples

# %% [markdown]
# # Compare FlowRES to Direct Integration

# %%
# Load in Direct Integration data for comparison
Validation_histogram = np.load(sys.path[0] + '/Direct_Integration_Data/Validation_histogram.npy')    # load a histogram generated from 10000 direct integration paths
Direct_integration_histogram = np.load(sys.path[0] + '/Direct_Integration_Data/Direct_integration_histogram.npy')    # load a histogram generated from 50000 direct integration paths
Direct_Integration_JSD_vs_Proposals = np.load(sys.path[0] + '/Direct_Integration_Data/Direct_Integration_JSD_vs_Proposals.npy')    # load a JSD with validation ensemble against proposal number for direct integration

# %% [markdown]
# ## Plot JSDs with Validation Ensemble

# %%
bins = np.linspace(-2,2,200)
all_FlowRES_JSDs = np.zeros(num_iterations+1)

for i, FlowRES_histogram in enumerate(all_FlowRES_hists):    # plot a histogram for the FlowRES ensemble at each iteration and work out its JSD from the validation histogram
    all_FlowRES_JSDs[i] = JSD(FlowRES_histogram, Validation_histogram)
    
Num_Paths_Proposed_FlowRES = num_chains * np.arange(num_iterations+1)
FlowRES_JSD_vs_Proposals = np.stack([Num_Paths_Proposed_FlowRES, all_FlowRES_JSDs])

# %%
compare_JSDS(FlowRES_JSD_vs_Proposals, Direct_Integration_JSD_vs_Proposals)

# %% [markdown]
# ## FlowRES and Direct Integration Histograms

# %%
# plot histograms
Compare_Hists(FlowRES_histogram, Validation_histogram, bins, Double_Well,
              text=str(params['k_BH']) + r'$\ k_{\rm B} T_{\rm eff}$')

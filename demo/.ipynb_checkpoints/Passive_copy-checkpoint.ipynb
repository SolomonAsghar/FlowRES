# %% [markdown]
# ### Imports

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf

# %%
import sys
path_to_software_folder = sys.path[0][:-4] + 'software/'
sys.path.append(path_to_software_folder) # Add the software folder to path, note that outside of the "demo" folder you will need to manually set "path_to_software_folder"
from DoubleWell import DoubleWell
from ProcessingNets import *
from Network_Passive import *
from FlowRES_MCMC_Passive import *

# %% [markdown]
# # Define the model

# %%
start_point = [-1.0, 0, 0.000]
duration = 1.6
traj_len = 32
D_t = 0.15
mu = 0.1
v = 0.0
D_r = 2.0
dt = duration/traj_len
tran_coeff = np.sqrt(2*D_t*dt)
rot_coeff = np.sqrt(2*D_r*dt)
act_coeff = v*dt
pot_coeff = mu*dt
params = {'x_0' :  1.0,
          'k_x' :  2.0,
          'k_y' :  10.0,
          'k_BH' : 7.5,
          'target': 7.5}
Double_Well = DoubleWell(params=params)

# %%
params = {'x_0' :  1.0,
          'k_x' :  2.0,
          'k_y' :  10.0,
          'k_BH' : 7.5,
          'target': 7.5}
Double_Well = DoubleWell(params=params)
Double_Well.plot_energy_surface_DW()

# %% [markdown]
# # Create a network

# %%
Affine_Wave_params = {'num_filters': 32,
                      'kernel_size': 3,
                      'num_dilated_conv_layers': 3}

Num_Layers = 2    # number of scales
FLOWS_pre_LAYER = 1    # For passive, leave this as 1
Pos_flows_per_Flow = 10    # Number of complete positional flow steps
Ang_flows_per_Flow = 0.00    # Leave this as 0
CCs = 0.00    # For passive, leave this as 0
Pos_CC_per_Flow = 0.00    # For passive, leave this as 0
Ang_CC_per_Flow = 0.00    # Leave this as 0

Net = CreateFlowNet(Num_Layers, FLOWS_pre_LAYER,
                    Pos_flows_per_Flow, Ang_flows_per_Flow, 
                    CCs, Pos_CC_per_Flow, Ang_CC_per_Flow,
                    Affine_WaveNet=Wave_unit, Affine_WaveParams=Affine_Wave_params, 
                    potential_grad=Double_Well.batch_gradient,
                    start=start_point, tran_coeff=tran_coeff, rot_coeff=rot_coeff, act_coeff=act_coeff, pot_coeff=pot_coeff,
                    max_len=traj_len, dim=3)
# Out:
# ... creating network
# Network created.

# %% [markdown]
# # FlowRES

# %%
num_chains = 15000
FlowRES_Passive_DoubleWell = FlowRes_MCMC(Net, num_chains, Chain_Initialiser_Passive, Double_Well)
FlowRES_Passive_DoubleWell.Compile_ML_Model(batch_size=512, lr=0.001)

file_loc = sys.path[0]
FlowRES_Passive_DoubleWell.Explore(iterations=100, file_loc=file_loc)
# Out:
# 2024-02-22 21:36:32.276949: W tensorflow/c/c_api.cc:291] Operation '{name:'Sum/reduction_indices' id:31690 op device:{requested: '', assigned: ''} def:{{{node Sum/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-02-22 21:36:33.904792: W tensorflow/c/c_api.cc:291] Operation '{name:'Sum_2/reduction_indices' id:31703 op device:{requested: '', assigned: ''} def:{{{node Sum_2/reduction_indices}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [] values: 0>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# Iteration 1 / 100
# /home/cs-solomon.asghar/.local/lib/python3.7/site-packages/keras/engine/training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-02-22 21:36:34.935252: W tensorflow/c/c_api.cc:291] Operation '{name:'GatherV2_29' id:31685 op device:{requested: '', assigned: ''} def:{{{node GatherV2_29}} = GatherV2[Taxis=DT_INT32, Tindices=DT_INT64, Tparams=DT_FLOAT, _has_manual_control_dependencies=true, batch_dims=0](concatenate_5/concat, GatherV2_29/indices, GatherV2_29/axis)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-02-22 21:36:39.623596: W tensorflow/c/c_api.cc:291] Operation '{name:'concat_51' id:21806 op device:{requested: '', assigned: ''} def:{{{node concat_51}} = ConcatV2[N=2, T=DT_FLOAT, Tidx=DT_INT32, _has_manual_control_dependencies=true](reshape_2/Reshape, reshape_3/Reshape, concat_51/axis)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
#     accepted 81.52000000000001% of non-local proposals
# Train on 12272 samples
# 2024-02-22 21:36:58.677573: W tensorflow/c/c_api.cc:291] Operation '{name:'loss/mul' id:31747 op device:{requested: '', assigned: ''} def:{{{node loss/mul}} = Mul[T=DT_FLOAT, _has_manual_control_dependencies=true](loss/mul/x, loss/tf_op_layer_concat_51_loss/value)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-02-22 21:37:01.916546: W tensorflow/c/c_api.cc:291] Operation '{name:'training/Adam/conv1d_245/bias/m/Assign' id:45357 op device:{requested: '', assigned: ''} def:{{{node training/Adam/conv1d_245/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/conv1d_245/bias/m, training/Adam/conv1d_245/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 12272/12272 [==============================] - 28s 2ms/sample - loss: 31.5084
#
#     network trained with [reweighted] non-local samples
# Iteration 2 / 100
#     accepted 50.60666666666667% of non-local proposals
# Train on 14498 samples
# 14498/14498 [==============================] - 8s 582us/sample - loss: 29.4004
#
#     network trained with [reweighted] non-local samples
# Iteration 3 / 100
#     accepted 42.4% of non-local proposals
# Train on 14917 samples
# 14917/14917 [==============================] - 9s 582us/sample - loss: 27.0607
#
#     network trained with [reweighted] non-local samples
# Iteration 4 / 100
#     accepted 39.300000000000004% of non-local proposals
# Train on 14991 samples
# 14991/14991 [==============================] - 9s 583us/sample - loss: 24.8370
#
#     network trained with [reweighted] non-local samples
# Iteration 5 / 100
#     accepted 41.29333333333333% of non-local proposals
# Train on 14998 samples
# 14998/14998 [==============================] - 9s 583us/sample - loss: 22.3230
#
#     network trained with [reweighted] non-local samples
# Iteration 6 / 100
#     accepted 44.593333333333334% of non-local proposals
# Train on 14999 samples
# 14999/14999 [==============================] - 9s 582us/sample - loss: 19.4639
#
#     network trained with [reweighted] non-local samples
# Iteration 7 / 100
#     accepted 41.660000000000004% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 572us/sample - loss: 16.9321
#
#     network trained with [reweighted] non-local samples
# Iteration 8 / 100
#     accepted 40.19333333333333% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 569us/sample - loss: 14.4836
#
#     network trained with [reweighted] non-local samples
# Iteration 9 / 100
#     accepted 42.553333333333335% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 566us/sample - loss: 11.8775
#
#     network trained with [reweighted] non-local samples
# Iteration 10 / 100
#     accepted 44.49333333333333% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 565us/sample - loss: 8.7896
#
#     network trained with [reweighted] non-local samples
# Iteration 11 / 100
#     accepted 45.513333333333335% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 567us/sample - loss: 5.2351
#
#     network trained with [reweighted] non-local samples
# Iteration 12 / 100
#     accepted 41.160000000000004% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 565us/sample - loss: 1.7110
#
#     network trained with [reweighted] non-local samples
# Iteration 13 / 100
#     accepted 40.46666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 567us/sample - loss: -2.3408
#
#     network trained with [reweighted] non-local samples
# Iteration 14 / 100
#     accepted 41.6% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 566us/sample - loss: -7.9667
#
#     network trained with [reweighted] non-local samples
# Iteration 15 / 100
#     accepted 41.873333333333335% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 567us/sample - loss: -14.9436
#
#     network trained with [reweighted] non-local samples
# Iteration 16 / 100
#     accepted 44.38666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 567us/sample - loss: -25.0364
#
#     network trained with [reweighted] non-local samples
# Iteration 17 / 100
#     accepted 44.0% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 567us/sample - loss: -37.1509
#
#     network trained with [reweighted] non-local samples
# Iteration 18 / 100
#     accepted 44.03333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 568us/sample - loss: -50.1640
#
#     network trained with [reweighted] non-local samples
# Iteration 19 / 100
#     accepted 45.446666666666665% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 564us/sample - loss: -63.3027
#
#     network trained with [reweighted] non-local samples
# Iteration 20 / 100
#     accepted 45.513333333333335% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 565us/sample - loss: -74.4634
#
#     network trained with [reweighted] non-local samples
# Iteration 21 / 100
#     accepted 44.913333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 564us/sample - loss: -82.4099
#
#     network trained with [reweighted] non-local samples
# Iteration 22 / 100
#     accepted 46.95333333333333% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 566us/sample - loss: -88.6796
#
#     network trained with [reweighted] non-local samples
# Iteration 23 / 100
#     accepted 46.9% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 571us/sample - loss: -92.9422
#
#     network trained with [reweighted] non-local samples
# Iteration 24 / 100
#     accepted 46.89333333333333% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 569us/sample - loss: -95.9727
#
#     network trained with [reweighted] non-local samples
# Iteration 25 / 100
#     accepted 48.52666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 568us/sample - loss: -98.3211
#
#     network trained with [reweighted] non-local samples
# Iteration 26 / 100
#     accepted 46.373333333333335% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 570us/sample - loss: -100.1687
#
#     network trained with [reweighted] non-local samples
# Iteration 27 / 100
#     accepted 47.56% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 572us/sample - loss: -101.6364
#
#     network trained with [reweighted] non-local samples
# Iteration 28 / 100
#     accepted 48.66666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 567us/sample - loss: -102.3584
#
#     network trained with [reweighted] non-local samples
# Iteration 29 / 100
#     accepted 51.44% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 567us/sample - loss: -103.1539
#
#     network trained with [reweighted] non-local samples
# Iteration 30 / 100
#     accepted 49.346666666666664% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -103.5481
#
#     network trained with [reweighted] non-local samples
# Iteration 31 / 100
#     accepted 51.78666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -103.6162
#
#     network trained with [reweighted] non-local samples
# Iteration 32 / 100
#     accepted 52.513333333333335% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 571us/sample - loss: -103.4235
#
#     network trained with [reweighted] non-local samples
# Iteration 33 / 100
#     accepted 50.53333333333333% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 566us/sample - loss: -103.6270
#
#     network trained with [reweighted] non-local samples
# Iteration 34 / 100
#     accepted 50.160000000000004% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 575us/sample - loss: -103.6848
#
#     network trained with [reweighted] non-local samples
# Iteration 35 / 100
#     accepted 52.14% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 571us/sample - loss: -103.6576
#
#     network trained with [reweighted] non-local samples
# Iteration 36 / 100
#     accepted 51.72666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 582us/sample - loss: -103.7925
#
#     network trained with [reweighted] non-local samples
# Iteration 37 / 100
#     accepted 48.6% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 576us/sample - loss: -103.9315
#
#     network trained with [reweighted] non-local samples
# Iteration 38 / 100
#     accepted 51.526666666666664% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 572us/sample - loss: -103.9603
#
#     network trained with [reweighted] non-local samples
# Iteration 39 / 100
#     accepted 51.85999999999999% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 8s 566us/sample - loss: -103.7574
#
#     network trained with [reweighted] non-local samples
# Iteration 40 / 100
#     accepted 48.126666666666665% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -103.7763
#
#     network trained with [reweighted] non-local samples
# Iteration 41 / 100
#     accepted 51.306666666666665% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -103.6217
#
#     network trained with [reweighted] non-local samples
# Iteration 42 / 100
#     accepted 45.440000000000005% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 576us/sample - loss: -103.3515
#
#     network trained with [reweighted] non-local samples
# Iteration 43 / 100
#     accepted 50.28% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -103.1678
#
#     network trained with [reweighted] non-local samples
# Iteration 44 / 100
#     accepted 51.806666666666665% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -103.1643
#
#     network trained with [reweighted] non-local samples
# Iteration 45 / 100
#     accepted 50.46000000000001% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -103.2063
#
#     network trained with [reweighted] non-local samples
# Iteration 46 / 100
#     accepted 51.373333333333335% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 577us/sample - loss: -102.9993
#
#     network trained with [reweighted] non-local samples
# Iteration 47 / 100
#     accepted 52.74666666666666% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -102.8958
#
#     network trained with [reweighted] non-local samples
# Iteration 48 / 100
#     accepted 52.55333333333333% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -102.9070
#
#     network trained with [reweighted] non-local samples
# Iteration 49 / 100
#     accepted 51.93333333333333% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 581us/sample - loss: -102.8247
#
#     network trained with [reweighted] non-local samples
# Iteration 50 / 100
#     accepted 50.28666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 577us/sample - loss: -102.9112
#
#     network trained with [reweighted] non-local samples
# Iteration 51 / 100
#     accepted 51.22% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 577us/sample - loss: -102.8460
#
#     network trained with [reweighted] non-local samples
# Iteration 52 / 100
#     accepted 50.086666666666666% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.8220
#
#     network trained with [reweighted] non-local samples
# Iteration 53 / 100
#     accepted 53.64% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -102.8479
#
#     network trained with [reweighted] non-local samples
# Iteration 54 / 100
#     accepted 51.85999999999999% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.8501
#
#     network trained with [reweighted] non-local samples
# Iteration 55 / 100
#     accepted 54.80666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.8206
#
#     network trained with [reweighted] non-local samples
# Iteration 56 / 100
#     accepted 53.68000000000001% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -102.6544
#
#     network trained with [reweighted] non-local samples
# Iteration 57 / 100
#     accepted 53.626666666666665% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.5535
#
#     network trained with [reweighted] non-local samples
# Iteration 58 / 100
#     accepted 55.11333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.5215
#
#     network trained with [reweighted] non-local samples
# Iteration 59 / 100
#     accepted 55.95333333333333% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 581us/sample - loss: -102.5599
#
#     network trained with [reweighted] non-local samples
# Iteration 60 / 100
#     accepted 55.733333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 581us/sample - loss: -102.5603
#
#     network trained with [reweighted] non-local samples
# Iteration 61 / 100
#     accepted 55.80666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -102.5139
#
#     network trained with [reweighted] non-local samples
# Iteration 62 / 100
#     accepted 54.89333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 583us/sample - loss: -102.4142
#
#     network trained with [reweighted] non-local samples
# Iteration 63 / 100
#     accepted 55.06666666666666% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.3785
#
#     network trained with [reweighted] non-local samples
# Iteration 64 / 100
#     accepted 55.39333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.5114
#
#     network trained with [reweighted] non-local samples
# Iteration 65 / 100
#     accepted 55.44% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.4273
#
#     network trained with [reweighted] non-local samples
# Iteration 66 / 100
#     accepted 53.48666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 582us/sample - loss: -102.3827
#
#     network trained with [reweighted] non-local samples
# Iteration 67 / 100
#     accepted 56.28666666666666% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.1578
#
#     network trained with [reweighted] non-local samples
# Iteration 68 / 100
#     accepted 54.22666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 582us/sample - loss: -102.1957
#
#     network trained with [reweighted] non-local samples
# Iteration 69 / 100
#     accepted 56.11333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.1085
#
#     network trained with [reweighted] non-local samples
# Iteration 70 / 100
#     accepted 51.67333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 581us/sample - loss: -102.2075
#
#     network trained with [reweighted] non-local samples
# Iteration 71 / 100
#     accepted 53.43333333333333% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -102.0363
#
#     network trained with [reweighted] non-local samples
# Iteration 72 / 100
#     accepted 55.400000000000006% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 581us/sample - loss: -102.1343
#
#     network trained with [reweighted] non-local samples
# Iteration 73 / 100
#     accepted 55.60666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.1168
#
#     network trained with [reweighted] non-local samples
# Iteration 74 / 100
#     accepted 57.11333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 575us/sample - loss: -102.2218
#
#     network trained with [reweighted] non-local samples
# Iteration 75 / 100
#     accepted 60.36666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 581us/sample - loss: -102.1855
#
#     network trained with [reweighted] non-local samples
# Iteration 76 / 100
#     accepted 55.96% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.0862
#
#     network trained with [reweighted] non-local samples
# Iteration 77 / 100
#     accepted 57.03333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 577us/sample - loss: -102.1566
#
#     network trained with [reweighted] non-local samples
# Iteration 78 / 100
#     accepted 56.766666666666666% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.1603
#
#     network trained with [reweighted] non-local samples
# Iteration 79 / 100
#     accepted 57.24% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.2468
#
#     network trained with [reweighted] non-local samples
# Iteration 80 / 100
#     accepted 56.53333333333334% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.2651
#
#     network trained with [reweighted] non-local samples
# Iteration 81 / 100
#     accepted 58.96% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.2555
#
#     network trained with [reweighted] non-local samples
# Iteration 82 / 100
#     accepted 59.82666666666666% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.2045
#
#     network trained with [reweighted] non-local samples
# Iteration 83 / 100
#     accepted 59.473333333333336% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.1951
#
#     network trained with [reweighted] non-local samples
# Iteration 84 / 100
#     accepted 59.040000000000006% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 577us/sample - loss: -102.2322
#
#     network trained with [reweighted] non-local samples
# Iteration 85 / 100
#     accepted 56.04666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.2512
#
#     network trained with [reweighted] non-local samples
# Iteration 86 / 100
#     accepted 55.553333333333335% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.1910
#
#     network trained with [reweighted] non-local samples
# Iteration 87 / 100
#     accepted 60.24% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.1897
#
#     network trained with [reweighted] non-local samples
# Iteration 88 / 100
#     accepted 60.553333333333335% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -102.1589
#
#     network trained with [reweighted] non-local samples
# Iteration 89 / 100
#     accepted 60.73333333333333% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.2163
#
#     network trained with [reweighted] non-local samples
# Iteration 90 / 100
#     accepted 60.88666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.1459
#
#     network trained with [reweighted] non-local samples
# Iteration 91 / 100
#     accepted 57.12666666666667% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.0592
#
#     network trained with [reweighted] non-local samples
# Iteration 92 / 100
#     accepted 60.81999999999999% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -102.1481
#
#     network trained with [reweighted] non-local samples
# Iteration 93 / 100
#     accepted 60.78% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 574us/sample - loss: -102.3127
#
#     network trained with [reweighted] non-local samples
# Iteration 94 / 100
#     accepted 61.919999999999995% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 577us/sample - loss: -102.2085
#
#     network trained with [reweighted] non-local samples
# Iteration 95 / 100
#     accepted 62.44% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -102.1394
#
#     network trained with [reweighted] non-local samples
# Iteration 96 / 100
#     accepted 59.266666666666666% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.1959
#
#     network trained with [reweighted] non-local samples
# Iteration 97 / 100
#     accepted 61.82% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 577us/sample - loss: -102.2074
#
#     network trained with [reweighted] non-local samples
# Iteration 98 / 100
#     accepted 60.693333333333335% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 579us/sample - loss: -102.2186
#
#     network trained with [reweighted] non-local samples
# Iteration 99 / 100
#     accepted 62.18% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 578us/sample - loss: -102.1188
#
#     network trained with [reweighted] non-local samples
# Iteration 100 / 100
#     accepted 60.473333333333336% of non-local proposals
# Train on 15000 samples
# 15000/15000 [==============================] - 9s 580us/sample - loss: -102.1739
#
#     network trained with [reweighted] non-local samples

# %%
All_MCMC = np.load('/home/cs-solomon.asghar/FlowRES/demo_MCMC_samples.npy')

# %%
start_point
# Out:
# [-1.0, 0, 0.0]

# %%
bins = np.linspace(-2,2,200)
all_hists = np.zeros((np.shape(All_MCMC)[1], 199, 199))
all_clipped_rand_paths = []

for i, ensemble in enumerate(np.swapaxes(All_MCMC, 0,1)):
    clip_ensemble = clip_reac(ensemble, Double_Well)
    random_path_idx = np.random.randint(len(clip_ensemble))
    clipped_rand_path = np.concatenate([[start_point[:-1]], clip_ensemble[random_path_idx]])
    all_clipped_rand_paths.append([clipped_rand_path])
    hist = Hist2D(ensemble, bins)
    all_hists[i] = hist

# %%
import matplotlib as mpl
from matplotlib.colors import LinearSegmentedColormap, ListedColormap

plasma = mpl.colormaps['plasma']
plasma_new_colors = plasma(np.linspace(0,1,256)**0.5)
plasma_2 = ListedColormap(plasma_new_colors)

# %%
Plot_3(all_hists[-1], all_hists[-1], bins, Double_Well, True, cmap=plasma_2, norm = norm,
       text=r'$18\ k_{\rm B} T_{\rm eff}$', path=all_clipped_rand_paths[-1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1461105/3995640160.py in <module>
#       1 Plot_3(all_hists[-1], all_hists[-1], bins, Double_Well, True, cmap=plasma_2, norm = norm,
# ----> 2        text=r'$18\ k_{\rm B} T_{\rm eff}$', path=all_clipped_rand_paths[-1])
#
# /tmp/ipykernel_1461105/874454658.py in Plot_3(NF_Hist_2D, Target_Hist_2D, bins, potential, Add_Scale_Bar, cmap, norm, text, path)
#      45     barrier_height = int(potential.params['k_BH'] * 2)
#      46     main, ax1 = Plot_pc_Hist(NF_Hist_2D,  bins, c1='#3C91E6', lw=5, plot_target_well=True, potential=potential,
# ---> 47                  barrier_height=barrier_height, Add_Scale_Bar=Add_Scale_Bar, cmap=cmap, norm=norm, text=text)
#      48     ax1.plot(*path, color='white', linewidth=3)
#      49     Plot_pc_Hist(Target_Hist_2D, bins, plot_xy=False, c1='#FDAB33', linestyle= (0, (10,5)), alph=0.0, lw=6, Add_Scale_Bar=False, zorder=1, cmap=cmap, norm=norm, text=text)
#
# /tmp/ipykernel_1461105/874454658.py in Plot_pc_Hist(Hist_2D, bins, gs, figsize, c1, alph, plot_xy, linestyle, lw, plot_target_well, potential, barrier_height, Add_Scale_Bar, zorder, cmap, norm, text)
#     143             alt_energies = alt_energies.reshape((100,100))
#     144             ax1.contour(alt_X1grid, alt_X2grid, alt_energies, levels=[potential.params['target']], colors='white', linewidths=5, linestyles='--')
# --> 145             ax1.plot(-1,0, marker='X', color='white', edgecolor='black', linewidth=1, markersize=20)
#     146
#     147         # Add scale bar #
#
# /usr/local/anaconda3-2022.05/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# /usr/local/anaconda3-2022.05/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# /usr/local/anaconda3-2022.05/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# /usr/local/anaconda3-2022.05/lib/python3.7/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# /usr/local/anaconda3-2022.05/lib/python3.7/site-packages/matplotlib/axes/_base.py in <genexpr>(.0)
#     531         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                               {**kwargs, 'label': label})
# --> 533                   for j, label in enumerate(labels))
#     534
#     535         if return_kwargs:
#
# /usr/local/anaconda3-2022.05/lib/python3.7/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     349         default_dict = self._getdefaults(set(), kw)
#     350         self._setdefaults(default_dict, kw)
# --> 351         seg = mlines.Line2D(x, y, **kw)
#     352         return seg, kw
#     353
#
# /usr/local/anaconda3-2022.05/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391         # update kwargs before updating data to give the caller a
#     392         # chance to init axes (and hence unit support)
# --> 393         self.update(kwargs)
#     394         self.pickradius = pickradius
#     395         self.ind_offset = 0
#
# /usr/local/anaconda3-2022.05/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'edgecolor'

# %%
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.gridspec as gridspec

# %%
height_ratios = [0.75,2]
width_ratios = [2,0.75]
figsize = 8*(2.75/2)
plt.rcParams['figure.figsize'] = figsize,figsize*1.033
plt.rcParams['font.size'] = 25
gs = gridspec.GridSpec(2, 2, height_ratios=height_ratios, width_ratios=width_ratios) 
gs.update(wspace=0.0, hspace=0.0)

# %%
def Get_Density(counts, bins):
    '''
    Convert a count to a density
    '''
    return counts / (sum(counts) * np.diff(bins))

def Hist2D(Trajs, bins):
    Trajs = np.concatenate(Trajs)
    Trajs_x = Trajs[:,0].flatten()
    Trajs_y = Trajs[:,1].flatten()
    return np.histogram2d(Trajs_x, Trajs_y, bins, density=True)[0].T

def clip_reac(Trajs, potential, include_last=True, return_lens=False):
    '''
    Return a mask where only valid trajs are True
    '''
    energies = potential.energy(Trajs, input_mode='Batch')
    energy_mask = energies < potential.params['target']
    right_mask = Trajs[:,:,0] > 0
    r_e_mask = np.logical_and(energy_mask,right_mask)
    not_r_e_mask = np.logical_not(r_e_mask)
    unreactive_mask = np.all(not_r_e_mask, axis=1)
    reactive_mask = np.logical_not(unreactive_mask)
    
    reac_Trajs = Trajs[reactive_mask]
    arg_reactive = np.argwhere(r_e_mask[reactive_mask])
    ind_of_first_reac = np.unique(arg_reactive[:,0], return_index=True)[1]
    timestep_of_first_reac = arg_reactive[ind_of_first_reac,1]

    clipped_Trajs = []
    if include_last is True:
        timestep_of_first_reac += 1
    for traj, first in zip(reac_Trajs,timestep_of_first_reac):
        clipped_Trajs.append(traj[:first])
    
    if return_lens is False:
        return clipped_Trajs
    else:
        return clipped_Trajs, timestep_of_first_reac+1

def Plot_3(NF_Hist_2D, Target_Hist_2D, bins, potential, Add_Scale_Bar, cmap, norm, text, path):
    fsz = 33
    
    plt.rcParams['figure.figsize'] = figsize, figsize*1.03
    barrier_height = int(potential.params['k_BH'] * 2)
    main, ax1 = Plot_pc_Hist(NF_Hist_2D,  bins, c1='#3C91E6', lw=5, plot_target_well=True, potential=potential,
                 barrier_height=barrier_height, Add_Scale_Bar=Add_Scale_Bar, cmap=cmap, norm=norm, text=text)
    ax1.plot(*path, color='white', linewidth=3)
    Plot_pc_Hist(Target_Hist_2D, bins, plot_xy=False, c1='#FDAB33', linestyle= (0, (10,5)), alph=0.0, lw=6, Add_Scale_Bar=False, zorder=1, cmap=cmap, norm=norm, text=text)
    cbaxes = inset_axes(ax1,
                        width="80%",  # width = 10% of parent_bbox width
                        height="3.0%",  # height : 50%
                        loc='lower center')
    cb = plt.colorbar(main, cax=cbaxes, ticklocation='top', 
                      label=r'$\hat{\rho}(x,y)$', orientation="horizontal")
    cbarticks = list(np.arange(*cbaxes.get_xlim(), 0.5))
    highest_p1 = np.floor((cbaxes.get_xlim()[1])*10)/10
    if not cbarticks[-1] >= highest_p1:
        cbarticks += [highest_p1]
    cbartick_labels = [str(cbarticks[0])] + ['' for i in range(len(cbarticks)-2)] + [str(cbarticks[-1])]
    cb.set_ticks(cbarticks, labels=cbartick_labels, fontsize=fsz)
    cbaxes.tick_params(axis='both', colors='white')
    cb.outline.set_edgecolor('white')
    cb.set_label(r'$\hat{\rho}(x,y)$', color='white', labelpad=-15, fontsize=fsz)
    plt.show()
    
def Plot_pc_Hist(Hist_2D, bins, gs=gs, figsize=15, c1='blue', alph = 0.21, plot_xy=True, linestyle='solid', lw=5.0,
                 plot_target_well=False, potential=None, barrier_height=None, Add_Scale_Bar=True, zorder=1, cmap=None, norm=None, text=None):
    fsz = 33
    plt.rcParams['font.size'] = 35
    ypad = 20
    spine_color = '#0C0786'
    
    Counts_x = np.sum(Hist_2D, axis=0)
    Counts_y = np.sum(Hist_2D, axis=1)
    
    Counts_x = Get_Density(Counts_x, bins)
    Counts_y = Get_Density(Counts_y, bins)
    
    ax0 = plt.subplot(gs[0,0])
    ax1 = plt.subplot(gs[1,0])
    ax2 = plt.subplot(gs[1,1])

    # x 
    ax0.stairs(Counts_x, bins, color=c1, linewidth=lw, linestyle=linestyle, zorder=zorder)
    ax0.stairs(Counts_x, bins, color=c1, fill=True, alpha=alph, zorder=zorder)
    ax0.axes.get_xaxis().set_visible(False)
    ax0.set_xlim(bins[0],bins[-1])
    ax0.yaxis.label.set_color(spine_color)
    ax0.tick_params(axis='y', colors=spine_color)
    ax0.set_ylabel(r'$\rho(x)$', rotation=0, labelpad=-50, y=1.01)
    yticks = list(np.arange(*ax0.get_ylim(), 0.5)[1:])
    ytick_labels = ['' for i in range(len(yticks[:-1]))] + yticks[-1:]
    ax0.yaxis.set_ticks(yticks, labels=ytick_labels)
    
    # Move left y-axis and bottom x-axis to centre, passing through (0,0)
    ax0.spines['left'].set_position('center')
    # Eliminate upper and right axes
    ax0.spines['right'].set_color('none')
    ax0.spines['top'].set_color('none')
    ax0.spines['left'].set_linewidth(2.0)
    ax0.spines['left'].set_color(spine_color)
    ax0.yaxis.set_tick_params(width=2.0)
        
    # y 
    ax2.stairs(Counts_y, bins, color=c1, linewidth=lw, orientation='horizontal',  linestyle=linestyle, zorder=zorder)
    ax2.stairs(Counts_y, bins, color=c1, fill=True, alpha=alph, orientation='horizontal', zorder=zorder)
    ax2.axes.get_yaxis().set_visible(False)
    ax2.set_ylim(bins[0],bins[-1])
    ax2.xaxis.label.set_color(spine_color)
    ax2.tick_params(axis='x', colors=spine_color)
    
    ax2.set_xlabel(r'$\rho(y)$', labelpad=-65, x=1.3)
    ax2.xaxis.set_ticks([1])
    
    # Move left y-axis and bottom x-axis to centre, passing through (0,0)
    ax2.spines['bottom'].set_position('center')
    # Eliminate upper and right axes
    ax2.spines['right'].set_color('none')
    ax2.spines['top'].set_color('none')
    ax2.spines['bottom'].set_linewidth(2.0)
    ax2.spines['bottom'].set_color(spine_color)
    ax2.xaxis.set_tick_params(width=2.0)
    xticks = list(np.arange(*ax2.get_xlim(), 0.5)[1:])
    xtick_labels = ['' for i in range(len(xticks[:-1]))] + xticks[-1:]
    ax2.xaxis.set_ticks(xticks, labels=xtick_labels)
    
    
    if plot_xy is True:
        # x y
        main = ax1.imshow(Hist_2D, interpolation='nearest', origin='lower',
                   extent=[bins[0], bins[-1], bins[0], bins[-1]], cmap=cmap, norm=norm)
        ax1.set_xticks([])
        ax1.set_yticks([])
        
        if plot_target_well is True:
            x_lim=1.75
            alt_x_1s = np.linspace(0,x_lim, 100)
            x_2s = np.linspace(-x_lim,x_lim, 100)
            alt_X1grid, alt_X2grid = np.meshgrid(alt_x_1s, x_2s) 
            alt_Xs = np.vstack([alt_X1grid.flatten(), alt_X2grid.flatten()]).T
            alt_energies = potential.energy(alt_Xs)
            alt_energies = alt_energies.reshape((100,100))
            ax1.contour(alt_X1grid, alt_X2grid, alt_energies, levels=[potential.params['target']], colors='white', linewidths=5, linestyles='--')
            ax1.plot(-1,0, marker='X', color='white', edgecolor='black', linewidth=1, markersize=20)
                
        # Add scale bar #
        if Add_Scale_Bar is True:
            rect = patches.Rectangle((-1.85, 1.80), 1, 0.05, linewidth=1, edgecolor='None', facecolor='white')
            ax1.add_patch(rect)      
            ax1.text(-1.35, 1.725, "1", color='white', fontsize=fsz,
                     horizontalalignment='center', verticalalignment='top')
        
        ax1.text(1.85, 1.85, text, color='white',
                 horizontalalignment='right', verticalalignment='top')
        return main, ax1

# %% [markdown]
# # Compare FlowRES to Direct Integration

# %%
# plot of FlowRES with slider
# bar chart showing how many paths proposed

# %%
Plot_3
